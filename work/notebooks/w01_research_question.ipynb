# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OmRaj6666/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/OmRaj6666/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 119 (delta 35), reused 97 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I have chosen Lane 2 – Refresh / Content Opportunity Scoring because it focuses on helping content teams decide which pages should be reviewed first. Instead of refreshing every page, the goal is to prioritize pages using observable search and engagement signals such as impressions, CTR, content freshness, and engagement. This project will produce a ranked review queue with confidence scores and reason codes, making it useful as a decision-support tool rather than simply training a machine learning model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Research Question
#
# **Which content pages should be reviewed first based on observable search and engagement signals?**
#
# ### Decision
# Prioritize pages for content review.
#
# ### Unit of Analysis
# One content page.
#
# ### Output
# A ranked list of pages with an opportunity score, suggested action, confidence level, and reason codes.
#
# ### Action
# A content reviewer can refresh, expand, monitor, protect, or prune pages.
#
# ### Cost of a Wrong Recommendation
# False positives waste review time, while false negatives may leave important declining pages unnoticed.
#
# ### Why Machine Learning Helps
# Machine learning combines multiple search and engagement signals to rank pages better than simple rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Total Columns:", len(df.columns))
print("Declining Pages:", (df["trend_direction"] == "down").sum())
print("Average Impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Average Sessions (90d):", round(df["sessions_90d"].mean(), 2))
# Out:
# Total Pages: 30000
# Total Columns: 44
# Declining Pages: 16262
# Average Impressions (90d): 5200.37
# Average Sessions (90d): 37.07

# %% [markdown]
# This project is a decision-support system that ranks pages for review using observable search and engagement signals.
#
# The recommendations do not prove that refreshing a page will improve traffic.
#
# The project does not predict Google's algorithm. It only provides evidence-based recommendations that should be reviewed by humans.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
